# %%
# Once your data is clean, the next step is to reshape, 
# reformat, and reorder it as needed for analysis. 
# Pandas gives you plenty of flexible tools to do this.

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df2=df.sort_values("MonthlyCharges",ascending=True) # sort but changes index values

# %%
df2.reset_index()
# Out:
#       index  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0         0  6823-SIDFQ    Male              0      No         No      28
# 1         1  9764-REAFF  Female              0     Yes         No      59
# 2         2  0827-ITJPH    Male              0      No         No      36
# 3         3  9945-PSVIP  Female              0     Yes        Yes      25
# 4         4  0621-CXBKL  Female              0      No         No      53
# ...     ...         ...     ...            ...     ...        ...     ...
# 7038   7038  8199-ZLLSA    Male              0      No         No      67
# 7039   7039  5989-AXPUC  Female              0     Yes         No      68
# 7040   7040  5734-EJKXG  Female              0      No         No      61
# 7041   7041  8984-HPEMB  Female              0      No         No      71
# 7042   7042  7569-NMZYQ  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService  ...     DeviceProtection  \
# ...
