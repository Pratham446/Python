# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df[["gender","customerID","PaymentMethod"]].head() # selecting columns
# Out:
#    gender  customerID              PaymentMethod
# 0  Female  7590-VHVEG           Electronic check
# 1    Male  5575-GNVDE               Mailed check
# 2    Male  3668-QPYBK               Mailed check
# 3    Male  7795-CFOCW  Bank transfer (automatic)
# 4  Female  9237-HQITU           Electronic check

# %%
df.loc[1] # selecting rows
# Out:
# customerID            5575-GNVDE
# gender                      Male
# SeniorCitizen                  0
# Partner                       No
# Dependents                    No
# tenure                        34
# PhoneService                 Yes
# MultipleLines                 No
# InternetService              DSL
# OnlineSecurity               Yes
# OnlineBackup                  No
# DeviceProtection             Yes
# TechSupport                   No
# StreamingTV                   No
# StreamingMovies               No
# Contract                One year
# PaperlessBilling              No
# PaymentMethod       Mailed check
# MonthlyCharges             56.95
# TotalCharges              1889.5
# Churn                         No
# Name: 1, dtype: object

# %%
df.loc[8,'MonthlyCharges'] # seleta a specific cell using labels
# Out:
# 104.8

# %%
df.iloc[4,6 # seleta a specific cell using index position
# Out:
# 'Yes'

# %%
# Slicing using loc
df.loc[0:10 ,["customerID","gender","PaymentMethod","tenure"]]
# Out:
#     customerID  gender              PaymentMethod  tenure
# 0   7590-VHVEG  Female           Electronic check       1
# 1   5575-GNVDE    Male               Mailed check      34
# 2   3668-QPYBK    Male               Mailed check       2
# 3   7795-CFOCW    Male  Bank transfer (automatic)      45
# 4   9237-HQITU  Female           Electronic check       2
# 5   9305-CDSKC  Female           Electronic check       8
# 6   1452-KIOVK    Male    Credit card (automatic)      22
# 7   6713-OKOMC  Female               Mailed check      10
# 8   7892-POOKP  Female           Electronic check      28
# 9   6388-TABGU    Male  Bank transfer (automatic)      62
# 10  9763-GRSKD    Male               Mailed check      13

# %%
df.at[0,"gender"] # used to access single element ny label
# Out:
# 'Female'

# %%
df.iat[0,0] # by index
# Out:
# '7590-VHVEG'

# %%
# Filtering of data from large dataset

# %%
df[df['tenure']>60]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 9     6388-TABGU    Male              0      No        Yes      62
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 28    5248-YGIJN    Male              0     Yes         No      72
# 30    3841-NFECX  Female              1     Yes         No      71
# ...          ...     ...            ...     ...        ...     ...
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 9             Yes            No             DSL                  Yes  ...
# ...

# %%
df[df['tenure']>60]['customerID']
# Out:
# 9       6388-TABGU
# 15      3655-SNQYZ
# 17      9959-WOFKT
# 28      5248-YGIJN
# 30      3841-NFECX
#            ...
# 7028    9281-CEDRU
# 7034    0639-TSIQW
# 7037    2569-WGERO
# 7039    2234-XADUH
# 7042    3186-AJIEK
# Name: customerID, Length: 1407, dtype: object

# %%
df[(df['tenure']>71) & (df['MonthlyCharges']>118)]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4586  7569-NMZYQ  Female              0     Yes        Yes      72
# 6118  9924-JPRMC    Male              0      No         No      72
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4586          Yes           Yes     Fiber optic            Yes  ...
# 6118          Yes           Yes     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 4586              Yes         Yes         Yes             Yes  Two year
# 6118              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 4586              Yes  Bank transfer (automatic)         118.75       8672.45
# 6118              Yes           Electronic check         118.20       8547.15
#
#      Churn
# 4586    No
# 6118    No
#
# [2 rows x 21 columns]

# %%
# The .query() method in pandas lets you filter DataFrame rows using a string expression

# %%
df.query("tenure > 60")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 9     6388-TABGU    Male              0      No        Yes      62
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 28    5248-YGIJN    Male              0     Yes         No      72
# 30    3841-NFECX  Female              1     Yes         No      71
# ...          ...     ...            ...     ...        ...     ...
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 9             Yes            No             DSL                  Yes  ...
# ...

# %%
df.query("InternetService == 'DSL'")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 7     6713-OKOMC  Female              0      No         No      10
# ...          ...     ...            ...     ...        ...     ...
# 7029  2235-DWLJU  Female              1      No         No       6
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...
